# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *
# Out:
# 2022-11-06 23:34:00.596053: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')
testimages = testdata.values

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=20,zoom_range=0.1,width_shift_range=0.1,height_shift_range=0.1,
                  shear_range=0.1,horizontal_flip=True,rescale=1/255.0,validation_split=0.1)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))
# Out:
# 2022-11-06 23:34:09.489307: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (BatchN  (None, 26, 26, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  flatten (Flatten)           (None, 10816)             0
#
#  batch_normalization_1 (Batc  (None, 10816)            43264
#  hNormalization)
#
#  dense (Dense)               (None, 256)               2769152
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 2,821,018
# Trainable params: 2,798,746
# Non-trainable params: 22,272
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy')>0.995):
      print("\nReached 99.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=40,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/40
# 773/773 [==============================] - 16s 20ms/step - loss: 1.4485 - accuracy: 0.5576 - val_loss: 2.0675 - val_accuracy: 0.3763
# Epoch 2/40
# 773/773 [==============================] - 15s 19ms/step - loss: 0.6603 - accuracy: 0.7861 - val_loss: 3.8985 - val_accuracy: 0.3388
# Epoch 3/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.4749 - accuracy: 0.8468 - val_loss: 0.5475 - val_accuracy: 0.8222
# Epoch 4/40
# 773/773 [==============================] - 14s 17ms/step - loss: 0.3817 - accuracy: 0.8739 - val_loss: 0.9853 - val_accuracy: 0.6947
# Epoch 5/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.3237 - accuracy: 0.8927 - val_loss: 0.9299 - val_accuracy: 0.7027
# Epoch 6/40
# 773/773 [==============================] - 15s 20ms/step - loss: 0.2883 - accuracy: 0.9054 - val_loss: 0.3411 - val_accuracy: 0.8867
# Epoch 7/40
# 773/773 [==============================] - 15s 19ms/step - loss: 0.2573 - accuracy: 0.9176 - val_loss: 0.7257 - val_accuracy: 0.7960
# Epoch 8/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.2375 - accuracy: 0.9216 - val_loss: 0.6584 - val_accuracy: 0.7971
# Epoch 9/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.2176 - accuracy: 0.9282 - val_loss: 3.1835 - val_accuracy: 0.4809
# Epoch 10/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1998 - accuracy: 0.9338 - val_loss: 0.3469 - val_accuracy: 0.8882
# Epoch 11/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.2008 - accuracy: 0.9335 - val_loss: 0.2504 - val_accuracy: 0.9148
# Epoch 12/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1859 - accuracy: 0.9393 - val_loss: 0.2573 - val_accuracy: 0.9199
# Epoch 13/40
# 773/773 [==============================] - 14s 19ms/step - loss: 0.1728 - accuracy: 0.9427 - val_loss: 0.8568 - val_accuracy: 0.7785
# Epoch 14/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1977 - accuracy: 0.9343 - val_loss: 0.4638 - val_accuracy: 0.8692
# Epoch 15/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1631 - accuracy: 0.9458 - val_loss: 0.5236 - val_accuracy: 0.8313
# Epoch 16/40
# 773/773 [==============================] - 15s 19ms/step - loss: 0.1571 - accuracy: 0.9468 - val_loss: 0.2427 - val_accuracy: 0.9250
# Epoch 17/40
# 773/773 [==============================] - 14s 19ms/step - loss: 0.1491 - accuracy: 0.9509 - val_loss: 0.1840 - val_accuracy: 0.9403
# Epoch 18/40
# 773/773 [==============================] - 14s 19ms/step - loss: 0.1538 - accuracy: 0.9483 - val_loss: 0.2138 - val_accuracy: 0.9352
# Epoch 19/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1218 - accuracy: 0.9576 - val_loss: 0.4545 - val_accuracy: 0.8783
# Epoch 20/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1800 - accuracy: 0.9404 - val_loss: 0.5664 - val_accuracy: 0.8434
# Epoch 21/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1393 - accuracy: 0.9531 - val_loss: 0.4927 - val_accuracy: 0.8710
# Epoch 22/40
# 773/773 [==============================] - 162s 210ms/step - loss: 0.1328 - accuracy: 0.9553 - val_loss: 0.2358 - val_accuracy: 0.9246
# Epoch 23/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1178 - accuracy: 0.9593 - val_loss: 0.5869 - val_accuracy: 0.8408
# Epoch 24/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1262 - accuracy: 0.9586 - val_loss: 0.5327 - val_accuracy: 0.8434
# Epoch 25/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1170 - accuracy: 0.9613 - val_loss: 0.2167 - val_accuracy: 0.9344
# Epoch 26/40
# 773/773 [==============================] - 14s 19ms/step - loss: 0.1101 - accuracy: 0.9628 - val_loss: 0.3800 - val_accuracy: 0.8907
# Epoch 27/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1063 - accuracy: 0.9630 - val_loss: 0.2485 - val_accuracy: 0.9206
# Epoch 28/40
# 773/773 [==============================] - 14s 19ms/step - loss: 0.0963 - accuracy: 0.9673 - val_loss: 0.6135 - val_accuracy: 0.8543
# Epoch 29/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.1227 - accuracy: 0.9607 - val_loss: 0.2061 - val_accuracy: 0.9315
# Epoch 30/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0938 - accuracy: 0.9691 - val_loss: 0.7131 - val_accuracy: 0.8215
# Epoch 31/40
# 773/773 [==============================] - 15s 19ms/step - loss: 0.0973 - accuracy: 0.9673 - val_loss: 0.2615 - val_accuracy: 0.9250
# Epoch 32/40
# 773/773 [==============================] - 378s 490ms/step - loss: 0.0940 - accuracy: 0.9701 - val_loss: 0.2164 - val_accuracy: 0.9322
# Epoch 33/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0885 - accuracy: 0.9703 - val_loss: 0.3073 - val_accuracy: 0.9148
# Epoch 34/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0887 - accuracy: 0.9696 - val_loss: 0.2642 - val_accuracy: 0.9151
# Epoch 35/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0902 - accuracy: 0.9694 - val_loss: 0.3392 - val_accuracy: 0.8944
# Epoch 36/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0829 - accuracy: 0.9722 - val_loss: 0.0973 - val_accuracy: 0.9698
# Epoch 37/40
# 773/773 [==============================] - 15s 19ms/step - loss: 0.0767 - accuracy: 0.9739 - val_loss: 0.1539 - val_accuracy: 0.9552
# Epoch 38/40
# 773/773 [==============================] - 91s 118ms/step - loss: 0.0779 - accuracy: 0.9741 - val_loss: 0.5017 - val_accuracy: 0.8750
# Epoch 39/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0862 - accuracy: 0.9709 - val_loss: 0.3302 - val_accuracy: 0.9016
# Epoch 40/40
# 773/773 [==============================] - 14s 18ms/step - loss: 0.0835 - accuracy: 0.9720 - val_loss: 0.2122 - val_accuracy: 0.9352

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_10795/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 98.32682609558105

# %%
model.save('models\model1.h5')

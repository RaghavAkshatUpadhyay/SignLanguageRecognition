# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *
# Out:
# 2022-11-06 15:42:18.836629: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
# model.add(Conv2D(64,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(26,activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        640
#
#  batch_normalization_4 (Batc  (None, 26, 26, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       73856
#
#  batch_normalization_5 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  batch_normalization_6 (Batc  (None, 3200)             12800
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 256)               819456
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 915,226
# Trainable params: 907,930
# Non-trainable params: 7,296
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=60,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/60
# 687/687 [==============================] - 20s 28ms/step - loss: 2.7243 - accuracy: 0.2307 - val_loss: 2.3919 - val_accuracy: 0.2675
# Epoch 2/60
# 687/687 [==============================] - 19s 28ms/step - loss: 1.7957 - accuracy: 0.4251 - val_loss: 2.6645 - val_accuracy: 0.3043
# Epoch 3/60
# 687/687 [==============================] - 19s 28ms/step - loss: 1.4976 - accuracy: 0.5091 - val_loss: 1.5586 - val_accuracy: 0.5128
# Epoch 4/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.3386 - accuracy: 0.5582 - val_loss: 4.3728 - val_accuracy: 0.2380
# Epoch 5/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.2270 - accuracy: 0.5926 - val_loss: 1.5541 - val_accuracy: 0.5028
# Epoch 6/60
# 687/687 [==============================] - 19s 28ms/step - loss: 1.1369 - accuracy: 0.6206 - val_loss: 2.2321 - val_accuracy: 0.4078
# Epoch 7/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.0693 - accuracy: 0.6419 - val_loss: 2.4171 - val_accuracy: 0.3857
# Epoch 8/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.0312 - accuracy: 0.6559 - val_loss: 1.7305 - val_accuracy: 0.5097
# Epoch 9/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.9960 - accuracy: 0.6636 - val_loss: 6.6003 - val_accuracy: 0.4010
# Epoch 10/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.9580 - accuracy: 0.6745 - val_loss: 1.3523 - val_accuracy: 0.5471
# Epoch 11/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.9266 - accuracy: 0.6889 - val_loss: 0.8720 - val_accuracy: 0.7061
# Epoch 12/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.8829 - accuracy: 0.6994 - val_loss: 42.0816 - val_accuracy: 0.1575
# Epoch 13/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.8910 - accuracy: 0.6979 - val_loss: 1.3222 - val_accuracy: 0.5720
# Epoch 14/60
# 687/687 [==============================] - 21s 31ms/step - loss: 0.8505 - accuracy: 0.7118 - val_loss: 1.6955 - val_accuracy: 0.5187
# Epoch 15/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.8404 - accuracy: 0.7171 - val_loss: 0.6299 - val_accuracy: 0.7913
# Epoch 16/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.8204 - accuracy: 0.7209 - val_loss: 0.8541 - val_accuracy: 0.7055
# Epoch 17/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.7898 - accuracy: 0.7317 - val_loss: 1.1047 - val_accuracy: 0.6483
# Epoch 18/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.7507 - accuracy: 0.7447 - val_loss: 2.7645 - val_accuracy: 0.6307
# Epoch 19/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.7638 - accuracy: 0.7423 - val_loss: 7.5400 - val_accuracy: 0.5607
# Epoch 20/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.7454 - accuracy: 0.7470 - val_loss: 0.6039 - val_accuracy: 0.7948
# Epoch 21/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.7405 - accuracy: 0.7493 - val_loss: 1.1927 - val_accuracy: 0.6367
# Epoch 22/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.7128 - accuracy: 0.7572 - val_loss: 0.4390 - val_accuracy: 0.8680
# Epoch 23/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.6970 - accuracy: 0.7617 - val_loss: 0.6155 - val_accuracy: 0.8408
# Epoch 24/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6920 - accuracy: 0.7659 - val_loss: 0.4274 - val_accuracy: 0.8736
# Epoch 25/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6534 - accuracy: 0.7760 - val_loss: 11.5633 - val_accuracy: 0.4821
# Epoch 26/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.6554 - accuracy: 0.7748 - val_loss: 0.4807 - val_accuracy: 0.8410
# Epoch 27/60
# 687/687 [==============================] - 22s 32ms/step - loss: 0.6397 - accuracy: 0.7820 - val_loss: 1.1503 - val_accuracy: 0.7449
# Epoch 28/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6461 - accuracy: 0.7814 - val_loss: 0.6346 - val_accuracy: 0.7958
# Epoch 29/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6307 - accuracy: 0.7865 - val_loss: 0.4730 - val_accuracy: 0.8386
# Epoch 30/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.6155 - accuracy: 0.7868 - val_loss: 37.7001 - val_accuracy: 0.2014
# Epoch 31/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.6053 - accuracy: 0.7930 - val_loss: 0.4545 - val_accuracy: 0.8550
# Epoch 32/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.6033 - accuracy: 0.7944 - val_loss: 0.3235 - val_accuracy: 0.8964
# Epoch 33/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5879 - accuracy: 0.7999 - val_loss: 0.6729 - val_accuracy: 0.7656
# Epoch 34/60
# 687/687 [==============================] - 26s 38ms/step - loss: 0.5784 - accuracy: 0.8060 - val_loss: 0.8306 - val_accuracy: 0.7964
# Epoch 35/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5711 - accuracy: 0.8038 - val_loss: 0.6684 - val_accuracy: 0.7938
# Epoch 36/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5590 - accuracy: 0.8093 - val_loss: 0.3107 - val_accuracy: 0.8946
# Epoch 37/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5521 - accuracy: 0.8134 - val_loss: 0.5357 - val_accuracy: 0.8181
# Epoch 38/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5436 - accuracy: 0.8148 - val_loss: 0.7789 - val_accuracy: 0.7454
# Epoch 39/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5478 - accuracy: 0.8146 - val_loss: 0.4990 - val_accuracy: 0.8423
# Epoch 40/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5392 - accuracy: 0.8168 - val_loss: 0.6797 - val_accuracy: 0.7780
# Epoch 41/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5293 - accuracy: 0.8191 - val_loss: 42.0317 - val_accuracy: 0.3016
# Epoch 42/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5213 - accuracy: 0.8209 - val_loss: 1.1424 - val_accuracy: 0.7088
# Epoch 43/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5241 - accuracy: 0.8213 - val_loss: 1.6323 - val_accuracy: 0.6192
# Epoch 44/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5125 - accuracy: 0.8258 - val_loss: 0.3739 - val_accuracy: 0.8745
# Epoch 45/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5153 - accuracy: 0.8269 - val_loss: 0.2726 - val_accuracy: 0.9210
# Epoch 46/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4970 - accuracy: 0.8294 - val_loss: 0.4668 - val_accuracy: 0.8334
# Epoch 47/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4959 - accuracy: 0.8329 - val_loss: 0.4872 - val_accuracy: 0.8223
# Epoch 48/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5049 - accuracy: 0.8281 - val_loss: 0.3211 - val_accuracy: 0.8973
# Epoch 49/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4921 - accuracy: 0.8345 - val_loss: 0.5221 - val_accuracy: 0.8299
# Epoch 50/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5015 - accuracy: 0.8293 - val_loss: 0.4174 - val_accuracy: 0.8674
# Epoch 51/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4909 - accuracy: 0.8310 - val_loss: 1.1269 - val_accuracy: 0.7013
# Epoch 52/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4866 - accuracy: 0.8328 - val_loss: 0.3050 - val_accuracy: 0.9060
# Epoch 53/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4814 - accuracy: 0.8360 - val_loss: 1.8592 - val_accuracy: 0.5662
# Epoch 54/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4819 - accuracy: 0.8363 - val_loss: 0.4628 - val_accuracy: 0.8454
# Epoch 55/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4575 - accuracy: 0.8438 - val_loss: 0.9167 - val_accuracy: 0.8119
# Epoch 56/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4676 - accuracy: 0.8399 - val_loss: 0.4565 - val_accuracy: 0.8496
# Epoch 57/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4601 - accuracy: 0.8445 - val_loss: 1.0016 - val_accuracy: 0.7276
# Epoch 58/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4704 - accuracy: 0.8430 - val_loss: 0.3189 - val_accuracy: 0.8876
# Epoch 59/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4491 - accuracy: 0.8467 - val_loss: 0.6624 - val_accuracy: 0.8867
# Epoch 60/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4583 - accuracy: 0.8449 - val_loss: 0.2316 - val_accuracy: 0.9297

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_21306/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 97.54601120948792

# %%
model.save('models/model8.h5')

# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *
# Out:
# 2022-11-06 17:53:34.417738: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
# model.add(Conv2D(64,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))
# Out:
# 2022-11-06 17:53:41.295007: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (BatchN  (None, 26, 26, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_2 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 256)               33024
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 264,602
# Trainable params: 263,194
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=60,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/60
# 687/687 [==============================] - 20s 28ms/step - loss: 2.5192 - accuracy: 0.2415 - val_loss: 2.6513 - val_accuracy: 0.2235
# Epoch 2/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.6686 - accuracy: 0.4602 - val_loss: 2.5701 - val_accuracy: 0.3446
# Epoch 3/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.3257 - accuracy: 0.5567 - val_loss: 1.4225 - val_accuracy: 0.5314
# Epoch 4/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.1364 - accuracy: 0.6196 - val_loss: 1.6065 - val_accuracy: 0.5043
# Epoch 5/60
# 687/687 [==============================] - 18s 27ms/step - loss: 1.0100 - accuracy: 0.6617 - val_loss: 1.6156 - val_accuracy: 0.5114
# Epoch 6/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.9440 - accuracy: 0.6872 - val_loss: 1.1998 - val_accuracy: 0.5968
# Epoch 7/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.8544 - accuracy: 0.7139 - val_loss: 1.4058 - val_accuracy: 0.5667
# Epoch 8/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.8044 - accuracy: 0.7300 - val_loss: 1.2078 - val_accuracy: 0.6159
# Epoch 9/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.7732 - accuracy: 0.7377 - val_loss: 2.2659 - val_accuracy: 0.4316
# Epoch 10/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.7243 - accuracy: 0.7561 - val_loss: 1.0003 - val_accuracy: 0.6693
# Epoch 11/60
# 687/687 [==============================] - 21s 30ms/step - loss: 0.6913 - accuracy: 0.7685 - val_loss: 0.9319 - val_accuracy: 0.7062
# Epoch 12/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.6598 - accuracy: 0.7795 - val_loss: 0.7514 - val_accuracy: 0.7445
# Epoch 13/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.6254 - accuracy: 0.7873 - val_loss: 1.6371 - val_accuracy: 0.5591
# Epoch 14/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6015 - accuracy: 0.7965 - val_loss: 0.9460 - val_accuracy: 0.6924
# Epoch 15/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.5847 - accuracy: 0.8038 - val_loss: 0.6895 - val_accuracy: 0.7733
# Epoch 16/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.5656 - accuracy: 0.8074 - val_loss: 1.7910 - val_accuracy: 0.5565
# Epoch 17/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5501 - accuracy: 0.8154 - val_loss: 0.7100 - val_accuracy: 0.7727
# Epoch 18/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5291 - accuracy: 0.8231 - val_loss: 0.3967 - val_accuracy: 0.8680
# Epoch 19/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5266 - accuracy: 0.8222 - val_loss: 0.5011 - val_accuracy: 0.8294
# Epoch 20/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.5114 - accuracy: 0.8287 - val_loss: 0.9322 - val_accuracy: 0.7163
# Epoch 21/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4921 - accuracy: 0.8361 - val_loss: 0.5339 - val_accuracy: 0.8179
# Epoch 22/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4947 - accuracy: 0.8339 - val_loss: 0.4646 - val_accuracy: 0.8397
# Epoch 23/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.4797 - accuracy: 0.8397 - val_loss: 1.1272 - val_accuracy: 0.6746
# Epoch 24/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4788 - accuracy: 0.8388 - val_loss: 0.4400 - val_accuracy: 0.8550
# Epoch 25/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4637 - accuracy: 0.8429 - val_loss: 0.5452 - val_accuracy: 0.8233
# Epoch 26/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4535 - accuracy: 0.8500 - val_loss: 0.5147 - val_accuracy: 0.8243
# Epoch 27/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4428 - accuracy: 0.8508 - val_loss: 0.4694 - val_accuracy: 0.8443
# Epoch 28/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4435 - accuracy: 0.8495 - val_loss: 0.9198 - val_accuracy: 0.7097
# Epoch 29/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4291 - accuracy: 0.8571 - val_loss: 0.4403 - val_accuracy: 0.8594
# Epoch 30/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4107 - accuracy: 0.8621 - val_loss: 0.5772 - val_accuracy: 0.8066
# Epoch 31/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4156 - accuracy: 0.8600 - val_loss: 0.3751 - val_accuracy: 0.8756
# Epoch 32/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.4192 - accuracy: 0.8590 - val_loss: 0.3807 - val_accuracy: 0.8694
# Epoch 33/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3917 - accuracy: 0.8681 - val_loss: 0.5932 - val_accuracy: 0.8157
# Epoch 34/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.3962 - accuracy: 0.8679 - val_loss: 0.4876 - val_accuracy: 0.8383
# Epoch 35/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3786 - accuracy: 0.8707 - val_loss: 0.5567 - val_accuracy: 0.8206
# Epoch 36/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3915 - accuracy: 0.8686 - val_loss: 0.5481 - val_accuracy: 0.8257
# Epoch 37/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3685 - accuracy: 0.8758 - val_loss: 0.2889 - val_accuracy: 0.8997
# Epoch 38/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3849 - accuracy: 0.8708 - val_loss: 0.3507 - val_accuracy: 0.8802
# Epoch 39/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3709 - accuracy: 0.8730 - val_loss: 0.6206 - val_accuracy: 0.8031
# Epoch 40/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.3575 - accuracy: 0.8796 - val_loss: 0.5053 - val_accuracy: 0.8334
# Epoch 41/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3709 - accuracy: 0.8732 - val_loss: 2.7448 - val_accuracy: 0.4839
# Epoch 42/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3719 - accuracy: 0.8764 - val_loss: 1.5414 - val_accuracy: 0.6192
# Epoch 43/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3501 - accuracy: 0.8809 - val_loss: 0.3867 - val_accuracy: 0.8705
# Epoch 44/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3534 - accuracy: 0.8836 - val_loss: 0.2962 - val_accuracy: 0.9040
# Epoch 45/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3436 - accuracy: 0.8833 - val_loss: 0.2471 - val_accuracy: 0.9146
# Epoch 46/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3470 - accuracy: 0.8847 - val_loss: 0.4389 - val_accuracy: 0.8532
# Epoch 47/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3442 - accuracy: 0.8817 - val_loss: 0.2928 - val_accuracy: 0.9042
# Epoch 48/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3373 - accuracy: 0.8852 - val_loss: 0.3587 - val_accuracy: 0.8803
# Epoch 49/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3416 - accuracy: 0.8864 - val_loss: 0.7374 - val_accuracy: 0.7791
# Epoch 50/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3347 - accuracy: 0.8882 - val_loss: 0.8404 - val_accuracy: 0.7567
# Epoch 51/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3244 - accuracy: 0.8914 - val_loss: 0.5304 - val_accuracy: 0.8272
# Epoch 52/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3276 - accuracy: 0.8910 - val_loss: 0.5962 - val_accuracy: 0.8044
# Epoch 53/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3200 - accuracy: 0.8934 - val_loss: 0.2147 - val_accuracy: 0.9261
# Epoch 54/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.3296 - accuracy: 0.8891 - val_loss: 0.7126 - val_accuracy: 0.7969
# Epoch 55/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3138 - accuracy: 0.8947 - val_loss: 0.3629 - val_accuracy: 0.8793
# Epoch 56/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3258 - accuracy: 0.8923 - val_loss: 0.2255 - val_accuracy: 0.9246
# Epoch 57/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3054 - accuracy: 0.8982 - val_loss: 0.2108 - val_accuracy: 0.9313
# Epoch 58/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3052 - accuracy: 0.8992 - val_loss: 0.6947 - val_accuracy: 0.7953
# Epoch 59/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3060 - accuracy: 0.8962 - val_loss: 0.2468 - val_accuracy: 0.9188
# Epoch 60/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3014 - accuracy: 0.8992 - val_loss: 0.2641 - val_accuracy: 0.9139

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_40439/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 97.88064956665039

# %%
history2=model.fit(traindata_generator,epochs=100,validation_data=validationdata_generator,callbacks=[callback],initial_epoch=60)
# Out:
# Epoch 61/100
# 687/687 [==============================] - 20s 30ms/step - loss: 0.2358 - accuracy: 0.9202 - val_loss: 0.1670 - val_accuracy: 0.9463
# Epoch 62/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2470 - accuracy: 0.9175 - val_loss: 0.1803 - val_accuracy: 0.9377
# Epoch 63/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.2384 - accuracy: 0.9210 - val_loss: 0.2077 - val_accuracy: 0.9262
# Epoch 64/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2346 - accuracy: 0.9207 - val_loss: 0.2376 - val_accuracy: 0.9202
# Epoch 65/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2383 - accuracy: 0.9226 - val_loss: 0.2717 - val_accuracy: 0.9049
# Epoch 66/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2381 - accuracy: 0.9218 - val_loss: 0.2989 - val_accuracy: 0.9006
# Epoch 67/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2372 - accuracy: 0.9192 - val_loss: 0.1660 - val_accuracy: 0.9448
# Epoch 68/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2264 - accuracy: 0.9237 - val_loss: 0.2013 - val_accuracy: 0.9281
# Epoch 69/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2393 - accuracy: 0.9201 - val_loss: 1.1054 - val_accuracy: 0.6808
# Epoch 70/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2289 - accuracy: 0.9243 - val_loss: 0.1903 - val_accuracy: 0.9343
# Epoch 71/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2364 - accuracy: 0.9193 - val_loss: 0.3179 - val_accuracy: 0.8913
# Epoch 72/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2324 - accuracy: 0.9244 - val_loss: 0.1324 - val_accuracy: 0.9557
# Epoch 73/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2228 - accuracy: 0.9269 - val_loss: 0.1758 - val_accuracy: 0.9379
# Epoch 74/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2270 - accuracy: 0.9229 - val_loss: 0.1905 - val_accuracy: 0.9383
# Epoch 75/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2209 - accuracy: 0.9263 - val_loss: 0.1415 - val_accuracy: 0.9536
# Epoch 76/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2147 - accuracy: 0.9269 - val_loss: 0.1693 - val_accuracy: 0.9454
# Epoch 77/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2320 - accuracy: 0.9238 - val_loss: 0.4725 - val_accuracy: 0.8541
# Epoch 78/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2245 - accuracy: 0.9213 - val_loss: 0.1905 - val_accuracy: 0.9390
# Epoch 79/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2218 - accuracy: 0.9260 - val_loss: 0.1892 - val_accuracy: 0.9364
# Epoch 80/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2209 - accuracy: 0.9269 - val_loss: 0.1182 - val_accuracy: 0.9614
# Epoch 81/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2356 - accuracy: 0.9209 - val_loss: 0.1197 - val_accuracy: 0.9592
# Epoch 82/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2106 - accuracy: 0.9267 - val_loss: 0.1446 - val_accuracy: 0.9519
# Epoch 83/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2196 - accuracy: 0.9263 - val_loss: 0.1894 - val_accuracy: 0.9364
# Epoch 84/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2207 - accuracy: 0.9268 - val_loss: 0.1339 - val_accuracy: 0.9563
# Epoch 85/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2178 - accuracy: 0.9257 - val_loss: 0.2430 - val_accuracy: 0.9180
# Epoch 86/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2131 - accuracy: 0.9287 - val_loss: 0.2409 - val_accuracy: 0.9210
# Epoch 87/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2123 - accuracy: 0.9285 - val_loss: 0.1745 - val_accuracy: 0.9426
# Epoch 88/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2082 - accuracy: 0.9300 - val_loss: 0.1687 - val_accuracy: 0.9417
# Epoch 89/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2128 - accuracy: 0.9292 - val_loss: 0.1017 - val_accuracy: 0.9669
# Epoch 90/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2152 - accuracy: 0.9261 - val_loss: 0.1398 - val_accuracy: 0.9539
# Epoch 91/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2173 - accuracy: 0.9283 - val_loss: 0.1210 - val_accuracy: 0.9607
# Epoch 92/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2100 - accuracy: 0.9313 - val_loss: 0.0854 - val_accuracy: 0.9716
# Epoch 93/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2052 - accuracy: 0.9314 - val_loss: 0.1625 - val_accuracy: 0.9474
# Epoch 94/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2117 - accuracy: 0.9290 - val_loss: 0.3424 - val_accuracy: 0.8896
# Epoch 95/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2146 - accuracy: 0.9264 - val_loss: 0.1095 - val_accuracy: 0.9647
# Epoch 96/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.1992 - accuracy: 0.9326 - val_loss: 0.1460 - val_accuracy: 0.9534
# Epoch 97/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2137 - accuracy: 0.9285 - val_loss: 0.3201 - val_accuracy: 0.8973
# Epoch 98/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2095 - accuracy: 0.9308 - val_loss: 0.1052 - val_accuracy: 0.9658
# Epoch 99/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2140 - accuracy: 0.9297 - val_loss: 0.1168 - val_accuracy: 0.9619
# Epoch 100/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.1983 - accuracy: 0.9335 - val_loss: 0.1504 - val_accuracy: 0.9470

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_40439/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 98.80089163780212

# %%
model.save('models/model10.h5')

# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# shear_range is different different to change augmentation
# validation split is differet that allows us to randomly split a subset of your training data into a validation set

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (BatchN  (None, 26, 26, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  batch_normalization_2 (Batc  (None, 3200)             12800
#  hNormalization)
#
#  dense (Dense)               (None, 256)               819456
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 915,226
# Trainable params: 907,930
# Non-trainable params: 7,296
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=40,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/40
# 687/687 [==============================] - 29s 40ms/step - loss: 2.1910 - accuracy: 0.3365 - val_loss: 2.9668 - val_accuracy: 0.1949
# Epoch 2/40
# 687/687 [==============================] - 27s 39ms/step - loss: 1.2266 - accuracy: 0.6024 - val_loss: 1.9101 - val_accuracy: 0.4728
# Epoch 3/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.8954 - accuracy: 0.7037 - val_loss: 1.1313 - val_accuracy: 0.6420
# Epoch 4/40
# 687/687 [==============================] - 24s 35ms/step - loss: 0.7487 - accuracy: 0.7542 - val_loss: 1.3551 - val_accuracy: 0.5984
# Epoch 5/40
# 687/687 [==============================] - 23s 33ms/step - loss: 0.6567 - accuracy: 0.7811 - val_loss: 1.3282 - val_accuracy: 0.6119
# Epoch 6/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.5755 - accuracy: 0.8075 - val_loss: 2.4764 - val_accuracy: 0.4648
# Epoch 7/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.5134 - accuracy: 0.8258 - val_loss: 0.7586 - val_accuracy: 0.7605
# Epoch 8/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.4698 - accuracy: 0.8437 - val_loss: 1.1420 - val_accuracy: 0.6461
# Epoch 9/40
# 687/687 [==============================] - 24s 35ms/step - loss: 0.4555 - accuracy: 0.8461 - val_loss: 0.9238 - val_accuracy: 0.7197
# Epoch 10/40
# 687/687 [==============================] - 24s 35ms/step - loss: 0.4264 - accuracy: 0.8574 - val_loss: 0.4680 - val_accuracy: 0.8408
# Epoch 11/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.4123 - accuracy: 0.8606 - val_loss: 1.5005 - val_accuracy: 0.6369
# Epoch 12/40
# 687/687 [==============================] - 24s 34ms/step - loss: 0.3650 - accuracy: 0.8764 - val_loss: 3.2467 - val_accuracy: 0.5782
# Epoch 13/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.3548 - accuracy: 0.8814 - val_loss: 0.6582 - val_accuracy: 0.7988
# Epoch 14/40
# 687/687 [==============================] - 24s 35ms/step - loss: 0.3441 - accuracy: 0.8825 - val_loss: 0.7520 - val_accuracy: 0.7674
# Epoch 15/40
# 687/687 [==============================] - 23s 33ms/step - loss: 0.3357 - accuracy: 0.8890 - val_loss: 1.1845 - val_accuracy: 0.6751
# Epoch 16/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.3128 - accuracy: 0.8947 - val_loss: 0.7595 - val_accuracy: 0.7676
# Epoch 17/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.3229 - accuracy: 0.8904 - val_loss: 0.7246 - val_accuracy: 0.7782
# Epoch 18/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2891 - accuracy: 0.9040 - val_loss: 0.4956 - val_accuracy: 0.8661
# Epoch 19/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2839 - accuracy: 0.9027 - val_loss: 0.4196 - val_accuracy: 0.8610
# Epoch 20/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2700 - accuracy: 0.9098 - val_loss: 0.6251 - val_accuracy: 0.8210
# Epoch 21/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2519 - accuracy: 0.9144 - val_loss: 2.2807 - val_accuracy: 0.8177
# Epoch 22/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2512 - accuracy: 0.9151 - val_loss: 2.3936 - val_accuracy: 0.5556
# Epoch 23/40
# 687/687 [==============================] - 21s 31ms/step - loss: 0.2452 - accuracy: 0.9175 - val_loss: 1.3743 - val_accuracy: 0.8206
# Epoch 24/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2433 - accuracy: 0.9192 - val_loss: 1.2864 - val_accuracy: 0.7361
# Epoch 25/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2274 - accuracy: 0.9235 - val_loss: 1.1255 - val_accuracy: 0.6675
# Epoch 26/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2265 - accuracy: 0.9251 - val_loss: 0.9489 - val_accuracy: 0.7554
# Epoch 27/40
# 687/687 [==============================] - 22s 32ms/step - loss: 0.2065 - accuracy: 0.9303 - val_loss: 0.4940 - val_accuracy: 0.8450
# Epoch 28/40
# 687/687 [==============================] - 23s 34ms/step - loss: 0.2117 - accuracy: 0.9280 - val_loss: 0.3529 - val_accuracy: 0.8896
# Epoch 29/40
# 687/687 [==============================] - 21s 31ms/step - loss: 0.2101 - accuracy: 0.9294 - val_loss: 1.3201 - val_accuracy: 0.6829
# Epoch 30/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1992 - accuracy: 0.9323 - val_loss: 0.2644 - val_accuracy: 0.9179
# Epoch 31/40
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1972 - accuracy: 0.9333 - val_loss: 0.5227 - val_accuracy: 0.8361
# Epoch 32/40
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1912 - accuracy: 0.9363 - val_loss: 0.5468 - val_accuracy: 0.8288
# Epoch 33/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1931 - accuracy: 0.9345 - val_loss: 0.4864 - val_accuracy: 0.8503
# Epoch 34/40
# 687/687 [==============================] - 21s 31ms/step - loss: 0.1889 - accuracy: 0.9384 - val_loss: 0.2810 - val_accuracy: 0.9108
# Epoch 35/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1815 - accuracy: 0.9389 - val_loss: 0.4830 - val_accuracy: 0.8569
# Epoch 36/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1862 - accuracy: 0.9383 - val_loss: 2.8564 - val_accuracy: 0.5269
# Epoch 37/40
# 687/687 [==============================] - 21s 31ms/step - loss: 0.1717 - accuracy: 0.9423 - val_loss: 1.4830 - val_accuracy: 0.7982
# Epoch 38/40
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1726 - accuracy: 0.9400 - val_loss: 2.4437 - val_accuracy: 0.6212
# Epoch 39/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1694 - accuracy: 0.9434 - val_loss: 0.6504 - val_accuracy: 0.8150
# Epoch 40/40
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1647 - accuracy: 0.9440 - val_loss: 0.3647 - val_accuracy: 0.8771

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_19884\141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 94.6040153503418

# %%
model.save('models\model4.h5')

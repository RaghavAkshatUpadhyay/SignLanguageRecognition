# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *
# Out:
# 2022-11-06 15:30:49.773638: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
# model.add(Conv2D(64,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))
# Out:
# 2022-11-06 15:32:52.748004: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (BatchN  (None, 26, 26, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  batch_normalization_2 (Batc  (None, 3200)             12800
#  hNormalization)
#
#  dropout (Dropout)           (None, 3200)              0
#
#  dense (Dense)               (None, 256)               819456
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 915,226
# Trainable params: 907,930
# Non-trainable params: 7,296
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=60,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/60
# 687/687 [==============================] - 21s 29ms/step - loss: 2.3493 - accuracy: 0.2944 - val_loss: 6.7136 - val_accuracy: 0.0605
# Epoch 2/60
# 687/687 [==============================] - 19s 27ms/step - loss: 1.5052 - accuracy: 0.5169 - val_loss: 3.6785 - val_accuracy: 0.2575
# Epoch 3/60
# 687/687 [==============================] - 19s 28ms/step - loss: 1.1591 - accuracy: 0.6192 - val_loss: 1.4054 - val_accuracy: 0.5560
# Epoch 4/60
# 687/687 [==============================] - 19s 28ms/step - loss: 1.0103 - accuracy: 0.6630 - val_loss: 1.0948 - val_accuracy: 0.6418
# Epoch 5/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.8663 - accuracy: 0.7077 - val_loss: 30.1827 - val_accuracy: 0.1672
# Epoch 6/60
# 687/687 [==============================] - 22s 31ms/step - loss: 0.7941 - accuracy: 0.7322 - val_loss: 1.2558 - val_accuracy: 0.6152
# Epoch 7/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.7397 - accuracy: 0.7488 - val_loss: 40.3867 - val_accuracy: 0.1380
# Epoch 8/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6830 - accuracy: 0.7692 - val_loss: 0.9100 - val_accuracy: 0.6908
# Epoch 9/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.6267 - accuracy: 0.7878 - val_loss: 0.7875 - val_accuracy: 0.7447
# Epoch 10/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.5936 - accuracy: 0.7991 - val_loss: 0.6656 - val_accuracy: 0.7709
# Epoch 11/60
# 687/687 [==============================] - 21s 30ms/step - loss: 0.5801 - accuracy: 0.8022 - val_loss: 0.5511 - val_accuracy: 0.8104
# Epoch 12/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.5514 - accuracy: 0.8134 - val_loss: 1.0476 - val_accuracy: 0.6833
# Epoch 13/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.5196 - accuracy: 0.8248 - val_loss: 0.8867 - val_accuracy: 0.7170
# Epoch 14/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.5379 - accuracy: 0.8179 - val_loss: 0.8161 - val_accuracy: 0.7345
# Epoch 15/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4962 - accuracy: 0.8323 - val_loss: 0.3591 - val_accuracy: 0.8862
# Epoch 16/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.4833 - accuracy: 0.8345 - val_loss: 0.4612 - val_accuracy: 0.8408
# Epoch 17/60
# 687/687 [==============================] - 21s 31ms/step - loss: 0.4615 - accuracy: 0.8426 - val_loss: 0.9658 - val_accuracy: 0.7042
# Epoch 18/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.4395 - accuracy: 0.8527 - val_loss: 0.6627 - val_accuracy: 0.7800
# Epoch 19/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.4280 - accuracy: 0.8572 - val_loss: 1.0651 - val_accuracy: 0.7092
# Epoch 20/60
# 687/687 [==============================] - 143s 208ms/step - loss: 0.4182 - accuracy: 0.8564 - val_loss: 0.2924 - val_accuracy: 0.9027
# Epoch 21/60
# 687/687 [==============================] - 28s 41ms/step - loss: 0.4157 - accuracy: 0.8590 - val_loss: 0.5302 - val_accuracy: 0.8335
# Epoch 22/60
# 687/687 [==============================] - 23s 34ms/step - loss: 0.4024 - accuracy: 0.8643 - val_loss: 0.6821 - val_accuracy: 0.7824
# Epoch 23/60
# 687/687 [==============================] - 45s 66ms/step - loss: 0.3865 - accuracy: 0.8693 - val_loss: 0.5577 - val_accuracy: 0.8155
# Epoch 24/60
# 687/687 [==============================] - 45s 66ms/step - loss: 0.3757 - accuracy: 0.8731 - val_loss: 0.5083 - val_accuracy: 0.8335
# Epoch 25/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.3508 - accuracy: 0.8808 - val_loss: 0.7864 - val_accuracy: 0.7680
# Epoch 26/60
# 687/687 [==============================] - 24s 35ms/step - loss: 0.3446 - accuracy: 0.8834 - val_loss: 0.2985 - val_accuracy: 0.8967
# Epoch 27/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3519 - accuracy: 0.8832 - val_loss: 0.4068 - val_accuracy: 0.8618
# Epoch 28/60
# 687/687 [==============================] - 22s 32ms/step - loss: 0.3478 - accuracy: 0.8823 - val_loss: 0.4011 - val_accuracy: 0.8574
# Epoch 29/60
# 687/687 [==============================] - 22s 31ms/step - loss: 0.3463 - accuracy: 0.8812 - val_loss: 1.0821 - val_accuracy: 0.6950
# Epoch 30/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.3337 - accuracy: 0.8870 - val_loss: 3.5970 - val_accuracy: 0.6288
# Epoch 31/60
# 687/687 [==============================] - 22s 32ms/step - loss: 0.3346 - accuracy: 0.8852 - val_loss: 1.4774 - val_accuracy: 0.6290
# Epoch 32/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.3141 - accuracy: 0.8937 - val_loss: 0.3842 - val_accuracy: 0.8725
# Epoch 33/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.3180 - accuracy: 0.8931 - val_loss: 0.2171 - val_accuracy: 0.9237
# Epoch 34/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.3108 - accuracy: 0.8942 - val_loss: 0.4082 - val_accuracy: 0.8623
# Epoch 35/60
# 687/687 [==============================] - 430s 627ms/step - loss: 0.3013 - accuracy: 0.8987 - val_loss: 0.8380 - val_accuracy: 0.7492
# Epoch 36/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.3013 - accuracy: 0.8972 - val_loss: 1.9400 - val_accuracy: 0.6403
# Epoch 37/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.2985 - accuracy: 0.8971 - val_loss: 1.0510 - val_accuracy: 0.7263
# Epoch 38/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2882 - accuracy: 0.9022 - val_loss: 0.3229 - val_accuracy: 0.8856
# Epoch 39/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2816 - accuracy: 0.9044 - val_loss: 0.5646 - val_accuracy: 0.8243
# Epoch 40/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2764 - accuracy: 0.9073 - val_loss: 0.1659 - val_accuracy: 0.9454
# Epoch 41/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2756 - accuracy: 0.9069 - val_loss: 1.3805 - val_accuracy: 0.6482
# Epoch 42/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2795 - accuracy: 0.9061 - val_loss: 0.2995 - val_accuracy: 0.9022
# Epoch 43/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2701 - accuracy: 0.9071 - val_loss: 0.3632 - val_accuracy: 0.8805
# Epoch 44/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2635 - accuracy: 0.9102 - val_loss: 0.3565 - val_accuracy: 0.8827
# Epoch 45/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2521 - accuracy: 0.9142 - val_loss: 0.2937 - val_accuracy: 0.8995
# Epoch 46/60
# 687/687 [==============================] - 19s 27ms/step - loss: 0.2616 - accuracy: 0.9114 - val_loss: 0.4358 - val_accuracy: 0.8569
# Epoch 47/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.2518 - accuracy: 0.9137 - val_loss: 0.4381 - val_accuracy: 0.8505
# Epoch 48/60
# 687/687 [==============================] - 20s 28ms/step - loss: 0.2486 - accuracy: 0.9157 - val_loss: 0.4342 - val_accuracy: 0.8632
# Epoch 49/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.2546 - accuracy: 0.9146 - val_loss: 0.3111 - val_accuracy: 0.8940
# Epoch 50/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.2512 - accuracy: 0.9167 - val_loss: 0.1583 - val_accuracy: 0.9457
# Epoch 51/60
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2539 - accuracy: 0.9154 - val_loss: 0.1590 - val_accuracy: 0.9465
# Epoch 52/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2369 - accuracy: 0.9209 - val_loss: 0.2337 - val_accuracy: 0.9221
# Epoch 53/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2312 - accuracy: 0.9222 - val_loss: 0.3362 - val_accuracy: 0.8884
# Epoch 54/60
# 687/687 [==============================] - 20s 29ms/step - loss: 0.2349 - accuracy: 0.9199 - val_loss: 0.2733 - val_accuracy: 0.9115
# Epoch 55/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2353 - accuracy: 0.9213 - val_loss: 0.1841 - val_accuracy: 0.9364
# Epoch 56/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2327 - accuracy: 0.9223 - val_loss: 0.2463 - val_accuracy: 0.9119
# Epoch 57/60
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2303 - accuracy: 0.9212 - val_loss: 0.2031 - val_accuracy: 0.9326
# Epoch 58/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2257 - accuracy: 0.9236 - val_loss: 0.2142 - val_accuracy: 0.9295
# Epoch 59/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2280 - accuracy: 0.9227 - val_loss: 0.2638 - val_accuracy: 0.9111
# Epoch 60/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2171 - accuracy: 0.9260 - val_loss: 0.4125 - val_accuracy: 0.8658

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_18845/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 94.88287568092346

# %%
history=model.fit(traindata_generator,epochs=100,validation_data=validationdata_generator,callbacks=[callback],initial_epoch=60)
# Out:
# Epoch 61/100
# 687/687 [==============================] - 20s 29ms/step - loss: 0.2228 - accuracy: 0.9255 - val_loss: 1.2403 - val_accuracy: 0.7070
# Epoch 62/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2277 - accuracy: 0.9235 - val_loss: 0.3509 - val_accuracy: 0.8875
# Epoch 63/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2252 - accuracy: 0.9251 - val_loss: 0.6458 - val_accuracy: 0.8055
# Epoch 64/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2223 - accuracy: 0.9231 - val_loss: 0.1172 - val_accuracy: 0.9596
# Epoch 65/100
# 687/687 [==============================] - 436s 636ms/step - loss: 0.2165 - accuracy: 0.9274 - val_loss: 0.3119 - val_accuracy: 0.8986
# Epoch 66/100
# 687/687 [==============================] - 20s 28ms/step - loss: 0.2134 - accuracy: 0.9272 - val_loss: 0.2691 - val_accuracy: 0.9129
# Epoch 67/100
# 687/687 [==============================] - 21s 30ms/step - loss: 0.2205 - accuracy: 0.9254 - val_loss: 0.3680 - val_accuracy: 0.8834
# Epoch 68/100
# 687/687 [==============================] - 19s 28ms/step - loss: 0.2184 - accuracy: 0.9260 - val_loss: 0.2743 - val_accuracy: 0.9064
# Epoch 69/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2107 - accuracy: 0.9292 - val_loss: 0.1163 - val_accuracy: 0.9614
# Epoch 70/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2130 - accuracy: 0.9279 - val_loss: 0.1241 - val_accuracy: 0.9594
# Epoch 71/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.2096 - accuracy: 0.9274 - val_loss: 0.2082 - val_accuracy: 0.9281
# Epoch 72/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2085 - accuracy: 0.9282 - val_loss: 0.1194 - val_accuracy: 0.9599
# Epoch 73/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.2173 - accuracy: 0.9274 - val_loss: 0.1350 - val_accuracy: 0.9579
# Epoch 74/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2048 - accuracy: 0.9292 - val_loss: 0.7572 - val_accuracy: 0.7922
# Epoch 75/100
# 687/687 [==============================] - 167s 243ms/step - loss: 0.1922 - accuracy: 0.9350 - val_loss: 1.3647 - val_accuracy: 0.8354
# Epoch 76/100
# 687/687 [==============================] - 21s 30ms/step - loss: 0.2044 - accuracy: 0.9314 - val_loss: 0.2648 - val_accuracy: 0.9168
# Epoch 77/100
# 687/687 [==============================] - 21s 31ms/step - loss: 0.2045 - accuracy: 0.9321 - val_loss: 0.3258 - val_accuracy: 0.8926
# Epoch 78/100
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2022 - accuracy: 0.9314 - val_loss: 0.5151 - val_accuracy: 0.8461
# Epoch 79/100
# 687/687 [==============================] - 18s 27ms/step - loss: 0.1991 - accuracy: 0.9330 - val_loss: 0.1712 - val_accuracy: 0.9430
# Epoch 80/100
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1955 - accuracy: 0.9324 - val_loss: 0.2874 - val_accuracy: 0.9078
# Epoch 81/100
# 687/687 [==============================] - 19s 28ms/step - loss: 0.1971 - accuracy: 0.9345 - val_loss: 0.1284 - val_accuracy: 0.9572
# Epoch 82/100
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1904 - accuracy: 0.9365 - val_loss: 0.8207 - val_accuracy: 0.7816
# Epoch 83/100
# 687/687 [==============================] - 22s 32ms/step - loss: 0.1947 - accuracy: 0.9350 - val_loss: 0.1584 - val_accuracy: 0.9472
# Epoch 84/100
# 687/687 [==============================] - 21s 31ms/step - loss: 0.1946 - accuracy: 0.9339 - val_loss: 0.6236 - val_accuracy: 0.8995
# Epoch 85/100
# 687/687 [==============================] - 20s 30ms/step - loss: 0.1894 - accuracy: 0.9364 - val_loss: 0.2506 - val_accuracy: 0.9131
# Epoch 86/100
# 687/687 [==============================] - 22s 32ms/step - loss: 0.1858 - accuracy: 0.9373 - val_loss: 0.8208 - val_accuracy: 0.7856
# Epoch 87/100
# 687/687 [==============================] - 21s 30ms/step - loss: 0.1830 - accuracy: 0.9380 - val_loss: 0.1199 - val_accuracy: 0.9618
# Epoch 88/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1781 - accuracy: 0.9395 - val_loss: 0.1480 - val_accuracy: 0.9521
# Epoch 89/100
# 687/687 [==============================] - 22s 32ms/step - loss: 0.1884 - accuracy: 0.9373 - val_loss: 1.3604 - val_accuracy: 0.7081
# Epoch 90/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1897 - accuracy: 0.9369 - val_loss: 0.6504 - val_accuracy: 0.8117
# Epoch 91/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1811 - accuracy: 0.9364 - val_loss: 0.1227 - val_accuracy: 0.9583
# Epoch 92/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1855 - accuracy: 0.9369 - val_loss: 0.1462 - val_accuracy: 0.9510
# Epoch 93/100
# 687/687 [==============================] - 19s 28ms/step - loss: 0.1773 - accuracy: 0.9407 - val_loss: 0.3156 - val_accuracy: 0.9040
# Epoch 94/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1809 - accuracy: 0.9386 - val_loss: 0.1064 - val_accuracy: 0.9634
# Epoch 95/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1764 - accuracy: 0.9410 - val_loss: 0.1224 - val_accuracy: 0.9598
# Epoch 96/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1803 - accuracy: 0.9405 - val_loss: 0.1731 - val_accuracy: 0.9410
# Epoch 97/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1815 - accuracy: 0.9407 - val_loss: 0.1430 - val_accuracy: 0.9512
# Epoch 98/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1803 - accuracy: 0.9409 - val_loss: 0.1380 - val_accuracy: 0.9519
# Epoch 99/100
# 687/687 [==============================] - 19s 27ms/step - loss: 0.1745 - accuracy: 0.9407 - val_loss: 0.3455 - val_accuracy: 0.8878
# Epoch 100/100
# 687/687 [==============================] - 20s 29ms/step - loss: 0.1740 - accuracy: 0.9408 - val_loss: 0.1912 - val_accuracy: 0.9364

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# /var/folders/s_/9hg8w5114qg8j3k5bh9xnv0w0000gn/T/ipykernel_18845/141321762.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 98.24316501617432

# %%
model.save('models/model7.h5')
